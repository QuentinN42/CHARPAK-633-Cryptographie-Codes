# %%
import os

os.chdir("../")

# %%
from base import decipher, Shift

# %%
for i in range(25):
    try:
        print(i, "\n\n", decipher("./data/message2.txt", Shift(-i)), "\n\n\n")
    except:
        pass
# Out:
# 0
#
#  *Jzi~w()(^w}{(i~m(lñkpqnnzñ(tm({mkwvl(um{{iom6^w}{(i}zm(xm}|5ò|zm(zmuizy}ñ(y}mty}m(kpw{m(liv{(tm(|m|m(y}m(~w}{(~mvm(lm(lñkpqnnzmz(B(tm({ujwtm(ixw{|zwxpm(ixxiziö|(|zð{({w}~mv|6(È(y}wq(kmti(m{|5qt(lă(è(~w|zm(i~q{(G(Kmti(kwv{|q|}m(}vm(niqjtm{{m(y}q(m{|(}vm(xwz|m(l/mv|zñm(xw}z(tm(kzx|ivit{|m6Ittm4(rm(~w}{(xzwxw{m(l/m{{imz(lm(lñkpqnnzmz(}v(i}|zm(|m|m4(|w}rw}z{({}z(tm(uòum(xzqvkqxm(l}(kwlm(lm(Kñ{iz6(Qt(v/m{|(~ziqumv|(xt}{(y}m{|qwv(lm(niqzm(tm(|zi~iqt(è(ti(uiqv6(Ïi(vm(lm~ziq|(xi{(~w}{(xw{mz(|zwx(lm(lqnnqk}t|ñ(lñ{wzuiq{655Rwót
#
#
#
# 1
#
# ...

# %%
print(decipher("./data/message2.txt", Shift(-8)))
# Out:
# "Bravo ! Vous avez déchiffré le second message.
#
# Vous aurez peut-être remarqué quelque chose dans le texte que vous venez de déchiffrer : le symbole apostrophe apparaît très souvent. À quoi cela est-il dû à votre avis ? Cela constitue une faiblesse qui est une porte d'entrée pour le cryptanalyste.
#
# Allez, je vous propose d'essayer de déchiffrer un autre texte, toujours sur le même principe du code de César. Il n'est vraiment plus question de faire le travail à la main. Ça ne devrait pas vous poser trop de difficulté désormais.
#
# --
# Joël
